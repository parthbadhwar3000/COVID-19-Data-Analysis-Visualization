# %%
import pandas as pd

# %%
df1=pd.read_csv('country_wise_latest.csv')

# %%
df1
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df1.head(5)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df1.dtypes
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# WHO Region                 object
# dtype: object

# %%
df1.isnull().any()
# Out:
# Country/Region            False
# Confirmed                 False
# Deaths                    False
# Recovered                 False
# Active                    False
# New cases                 False
# New deaths                False
# New recovered             False
# Deaths / 100 Cases        False
# Recovered / 100 Cases     False
# Deaths / 100 Recovered    False
# Confirmed last week       False
# 1 week change             False
# 1 week % increase         False
# WHO Region                False
# dtype: bool

# %%
df2=pd.read_csv('worldometer_data.csv')

# %%
df2
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
df2.dtypes
# Out:
# Country/Region       object
# Continent            object
# Population          float64
# TotalCases            int64
# NewCases            float64
# TotalDeaths         float64
# NewDeaths           float64
# TotalRecovered      float64
# NewRecovered        float64
# ActiveCases         float64
# Serious,Critical    float64
# Tot Cases/1M pop    float64
# Deaths/1M pop       float64
# TotalTests          float64
# Tests/1M pop        float64
# WHO Region           object
# dtype: object

# %%
df2.isnull().any()
# Out:
# Country/Region      False
# Continent            True
# Population           True
# TotalCases          False
# NewCases             True
# TotalDeaths          True
# NewDeaths            True
# TotalRecovered       True
# NewRecovered         True
# ActiveCases          True
# Serious,Critical     True
# Tot Cases/1M pop     True
# Deaths/1M pop        True
# TotalTests           True
# Tests/1M pop         True
# WHO Region           True
# dtype: bool

# %%
df2.isnull()
# Out:
#      Country/Region  Continent  Population  TotalCases  NewCases  TotalDeaths  \
# 0             False      False       False       False      True        False
# 1             False      False       False       False      True        False
# 2             False      False       False       False      True        False
# 3             False      False       False       False      True        False
# 4             False      False       False       False      True        False
# ..              ...        ...         ...         ...       ...          ...
# 204           False      False       False       False      True        False
# 205           False      False       False       False      True         True
# 206           False      False       False       False      True         True
# 207           False      False       False       False      True         True
# 208           False      False       False       False      True        False
#
# ...

# %%
df2_clean=df2.copy()

# %%
df2_clean=df2.fillna(0)

# %%
df2_clean
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       0.0
# 1                   Brazil  South America  2.127107e+08     2917562       0.0
# 2                    India           Asia  1.381345e+09     2025409       0.0
# 3                   Russia         Europe  1.459409e+08      871894       0.0
# 4             South Africa         Africa  5.938157e+07      538184       0.0
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       0.0
# 205  Caribbean Netherlands  North America  2.624700e+04          13       0.0
# 206       Falkland Islands  South America  3.489000e+03          13       0.0
# 207           Vatican City         Europe  8.010000e+02          12       0.0
# 208         Western Sahara         Africa  5.986820e+05          10       0.0
#
# ...

# %%
df2_clean.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       0.0
# 1         Brazil  South America  2.127107e+08     2917562       0.0
# 2          India           Asia  1.381345e+09     2025409       0.0
# 3         Russia         Europe  1.459409e+08      871894       0.0
# 4   South Africa         Africa  5.938157e+07      538184       0.0
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        0.0       2576668.0           0.0    2292707.0
# 1      98644.0        0.0       2047660.0           0.0     771258.0
# 2      41638.0        0.0       1377384.0           0.0     606387.0
# 3      14606.0        0.0        676357.0           0.0     180931.0
# 4       9604.0        0.0        387316.0           0.0     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
df1.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df1.dtypes
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# WHO Region                 object
# dtype: object

# %%
df1.rename(columns={'Country/Region': 'Country'},inplace=True)
df2_clean.rename(columns={'Country/Region': 'Country'},inplace=True)

# %%
df1.head()
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
# 2      Algeria      27973    1163      18837    7973        616           8
# 3      Andorra        907      52        803      52         10           0
# 4       Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df2_clean.head()
# Out:
#         Country      Continent    Population  TotalCases  NewCases  \
# 0           USA  North America  3.311981e+08     5032179       0.0
# 1        Brazil  South America  2.127107e+08     2917562       0.0
# 2         India           Asia  1.381345e+09     2025409       0.0
# 3        Russia         Europe  1.459409e+08      871894       0.0
# 4  South Africa         Africa  5.938157e+07      538184       0.0
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        0.0       2576668.0           0.0    2292707.0
# 1      98644.0        0.0       2047660.0           0.0     771258.0
# 2      41638.0        0.0       1377384.0           0.0     606387.0
# 3      14606.0        0.0        676357.0           0.0     180931.0
# 4       9604.0        0.0        387316.0           0.0     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
df1.dtypes
# Out:
# Country                    object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# WHO Region                 object
# dtype: object

# %%
df2_clean.dtypes
# Out:
# Country              object
# Continent            object
# Population          float64
# TotalCases            int64
# NewCases            float64
# TotalDeaths         float64
# NewDeaths           float64
# TotalRecovered      float64
# NewRecovered        float64
# ActiveCases         float64
# Serious,Critical    float64
# Tot Cases/1M pop    float64
# Deaths/1M pop       float64
# TotalTests          float64
# Tests/1M pop        float64
# WHO Region           object
# dtype: object

# %%
df2_clean.rename(columns={'TotalCases': 'Confirmed'},inplace=True)
df2_clean.rename(columns={'TotalDeaths': 'Deaths'},inplace=True)
df2_clean.rename(columns={'TotalRecovered': 'Recovered'},inplace=True)
df2_clean.rename(columns={'ActiveCases': 'Active'},inplace=True)
df1.rename(columns={'New cases': 'NewCases'},inplace=True)
df1.rename(columns={'New deaths': 'NewDeaths'},inplace=True)
df1.rename(columns={'New recovered': 'NewRecovered'},inplace=True)

# %%
df1.head()
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  NewCases  NewDeaths  \
# 0  Afghanistan      36263    1269      25198    9796       106         10
# 1      Albania       4880     144       2745    1991       117          6
# 2      Algeria      27973    1163      18837    7973       616          8
# 3      Andorra        907      52        803      52        10          0
# 4       Angola        950      41        242     667        18          1
#
#    NewRecovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0            18                3.50                  69.49
# 1            63                2.95                  56.25
# 2           749                4.16                  67.34
# 3             0                5.73                  88.53
# 4             0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df2_clean.head()
# Out:
#         Country      Continent    Population  Confirmed  NewCases    Deaths  \
# 0           USA  North America  3.311981e+08    5032179       0.0  162804.0
# 1        Brazil  South America  2.127107e+08    2917562       0.0   98644.0
# 2         India           Asia  1.381345e+09    2025409       0.0   41638.0
# 3        Russia         Europe  1.459409e+08     871894       0.0   14606.0
# 4  South Africa         Africa  5.938157e+07     538184       0.0    9604.0
#
#    NewDeaths  Recovered  NewRecovered     Active  Serious,Critical  \
# 0        0.0  2576668.0           0.0  2292707.0           18296.0
# 1        0.0  2047660.0           0.0   771258.0            8318.0
# 2        0.0  1377384.0           0.0   606387.0            8944.0
# 3        0.0   676357.0           0.0   180931.0            2300.0
# 4        0.0   387316.0           0.0   141264.0             539.0
#
#    Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop      WHO Region
# ...

# %%
df1.dtypes
# Out:
# Country                      object
# Confirmed                     int64
# Deaths                        int64
# Recovered                     int64
# Active                        int64
# NewCases                      int64
# NewDeaths                     int64
# NewRecovered                  int64
# Deaths_per_100_cases        float64
# Recovered_per_100_cases     float64
# Deaths_per_100_Recovered    float64
# Confirmed_last_week           int64
# 1_week_change                 int64
# 1_week_percent_increase     float64
# WHO_Region                   object
# dtype: object

# %%
df2_clean.dtypes
# Out:
# Country                  object
# Continent                object
# Population              float64
# Confirmed                 int64
# NewCases                float64
# Deaths                  float64
# NewDeaths               float64
# Recovered               float64
# NewRecovered            float64
# Active                  float64
# Serious,Critical        float64
# Tot_Cases_per_1M_pop    float64
# Deaths_per_1M_pop       float64
# TotalTests              float64
# Tests_per_1M_pop        float64
# WHO_Region               object
# dtype: object

# %%
df2_clean.rename(columns={'Tot Cases/1M pop':'Tot_Cases_per_1M_pop'},inplace=True)
df2_clean.rename(columns={'Deaths/1M pop':'Deaths_per_1M_pop'},inplace=True)
df2_clean.rename(columns={'Tests/1M pop':'Tests_per_1M_pop'},inplace=True)
df2_clean.rename(columns={'WHO Region':'WHO_Region'},inplace=True)

# %%
df1.rename(columns={'Deaths / 100 Cases': 'Deaths_per_100_cases'},inplace=True)
df1.rename(columns={'Recovered / 100 Cases': 'Recovered_per_100_cases'},inplace=True)
df1.rename(columns={'Deaths / 100 Recovered': 'Deaths_per_100_Recovered'},inplace=True)
df1.rename(columns={'Confirmed last week': 'Confirmed_last_week'},inplace=True)
df1.rename(columns={'1 week change': '1_week_change'},inplace=True)
df1.rename(columns={'1 week % increase': '1_week_percent_increase'},inplace=True)
df1.rename(columns={'WHO Region': 'WHO_Region'},inplace=True)

# %%
merged_data=pd.merge(df1,df2_clean,on="Country", how="inner")

# %%
merged_data
# Out:
#             Country  Confirmed_x  Deaths_x  Recovered_x  Active_x  NewCases_x  \
# 0       Afghanistan        36263      1269        25198      9796         106
# 1           Albania         4880       144         2745      1991         117
# 2           Algeria        27973      1163        18837      7973         616
# 3           Andorra          907        52          803        52          10
# 4            Angola          950        41          242       667          18
# ..              ...          ...       ...          ...       ...         ...
# 166         Vietnam          431         0          365        66          11
# 167  Western Sahara           10         1            8         1           0
# 168           Yemen         1691       483          833       375          10
# 169          Zambia         4552       140         2815      1597          71
# 170        Zimbabwe         2704        36          542      2126         192
#
# ...

# %%
merged_data.to_csv('merged_data.csv',index=False)

# %%
# Out:
# 0      9796
# 1      1991
# 2      7973
# 3        52
# 4       667
#        ...
# 182    6791
# 183       1
# 184     375
# 185    1597
# 186    2126
# Name: Active, Length: 187, dtype: int64

# %%
df1.head()
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  NewCases  NewDeaths  \
# 0  Afghanistan      36263    1269      25198    9796       106         10
# 1      Albania       4880     144       2745    1991       117          6
# 2      Algeria      27973    1163      18837    7973       616          8
# 3      Andorra        907      52        803      52        10          0
# 4       Angola        950      41        242     667        18          1
#
#    NewRecovered  Deaths_per_100_cases  Recovered_per_100_cases  \
# 0            18                  3.50                    69.49
# 1            63                  2.95                    56.25
# 2           749                  4.16                    67.34
# 3             0                  5.73                    88.53
# 4             0                  4.32                    25.47
#
#    Deaths_per_100_Recovered  Confirmed_last_week  1_week_change  \
# 0                      5.04                35526            737
# ...

# %%
df2_clean.head()
# Out:
#         Country      Continent    Population  Confirmed  NewCases    Deaths  \
# 0           USA  North America  3.311981e+08    5032179       0.0  162804.0
# 1        Brazil  South America  2.127107e+08    2917562       0.0   98644.0
# 2         India           Asia  1.381345e+09    2025409       0.0   41638.0
# 3        Russia         Europe  1.459409e+08     871894       0.0   14606.0
# 4  South Africa         Africa  5.938157e+07     538184       0.0    9604.0
#
#    NewDeaths  Recovered  NewRecovered     Active  Serious,Critical  \
# 0        0.0  2576668.0           0.0  2292707.0           18296.0
# 1        0.0  2047660.0           0.0   771258.0            8318.0
# 2        0.0  1377384.0           0.0   606387.0            8944.0
# 3        0.0   676357.0           0.0   180931.0            2300.0
# 4        0.0   387316.0           0.0   141264.0             539.0
#
#    Tot_Cases_per_1M_pop  Deaths_per_1M_pop  TotalTests  Tests_per_1M_pop  \
# ...

# %%
df1_sorted=df1.copy()
df1_sorted=df1.sort_values(by='Deaths',ascending=False)
df1_sorted
# Out:
#             Country  Confirmed  Deaths  Recovered   Active  NewCases  \
# 173              US    4290259  148011    1325804  2816444     56336
# 23           Brazil    2442375   87618    1846641   508116     23284
# 177  United Kingdom     301708   45844       1437   254427       688
# 111          Mexico     395489   44022     303810    47657      4973
# 85            Italy     246286   35112     198593    12581       168
# ..              ...        ...     ...        ...      ...       ...
# 94             Laos         20       0         19        1         0
# 68        Greenland         14       0         13        1         1
# 30         Cambodia        226       0        147       79         1
# 69          Grenada         23       0         23        0         0
# 114        Mongolia        289       0        222       67         1
#
#      NewDeaths  NewRecovered  Deaths_per_100_cases  Recovered_per_100_cases  \
# ...

# %%
df1['Country']=df1['Country'].replace({'US':'USA'})

# %%
df1_sorted=df1.sort_values(by='Deaths',ascending=False)

# %%
df1_sorted
# Out:
#             Country  Confirmed  Deaths  Recovered   Active  NewCases  \
# 173             USA    4290259  148011    1325804  2816444     56336
# 23           Brazil    2442375   87618    1846641   508116     23284
# 177  United Kingdom     301708   45844       1437   254427       688
# 111          Mexico     395489   44022     303810    47657      4973
# 85            Italy     246286   35112     198593    12581       168
# ..              ...        ...     ...        ...      ...       ...
# 94             Laos         20       0         19        1         0
# 68        Greenland         14       0         13        1         1
# 30         Cambodia        226       0        147       79         1
# 69          Grenada         23       0         23        0         0
# 114        Mongolia        289       0        222       67         1
#
#      NewDeaths  NewRecovered  Deaths_per_100_cases  Recovered_per_100_cases  \
# ...

# %%
merged_data=pd.merge(df1,df2_clean,on="Country",how="left")
merged_data.head()
# Out:
#        Country  Confirmed_x  Deaths_x  Recovered_x  Active_x  NewCases_x  \
# 0  Afghanistan        36263      1269        25198      9796         106
# 1      Albania         4880       144         2745      1991         117
# 2      Algeria        27973      1163        18837      7973         616
# 3      Andorra          907        52          803        52          10
# 4       Angola          950        41          242       667          18
#
#    NewDeaths_x  NewRecovered_x  Deaths_per_100_cases  Recovered_per_100_cases  \
# 0           10              18                  3.50                    69.49
# 1            6              63                  2.95                    56.25
# 2            8             749                  4.16                    67.34
# 3            0               0                  5.73                    88.53
# 4            1               0                  4.32                    25.47
#
# ...

# %%
merged_data.to_csv('merged_data.csv',index=False )

# %%
merged_data.isnull().any()
# Out:
# Country                     False
# Confirmed_x                 False
# Deaths_x                    False
# Recovered_x                 False
# Active_x                    False
# NewCases_x                  False
# NewDeaths_x                 False
# NewRecovered_x              False
# Deaths_per_100_cases        False
# Recovered_per_100_cases     False
# Deaths_per_100_Recovered    False
# Confirmed_last_week         False
# 1_week_change               False
# 1_week_percent_increase     False
# WHO_Region_x                False
# Continent                    True
# Population                   True
# Confirmed_y                  True
# NewCases_y                   True
# Deaths_y                     True
# NewDeaths_y                  True
# Recovered_y                  True
# NewRecovered_y               True
# Active_y                     True
# Serious,Critical             True
# Tot_Cases_per_1M_pop         True
# Deaths_per_1M_pop            True
# ...

# %%
merged_data.fillna(0)
# Out:
#                 Country  Confirmed_x  Deaths_x  Recovered_x  Active_x  \
# 0           Afghanistan        36263      1269        25198      9796
# 1               Albania         4880       144         2745      1991
# 2               Algeria        27973      1163        18837      7973
# 3               Andorra          907        52          803        52
# 4                Angola          950        41          242       667
# ..                  ...          ...       ...          ...       ...
# 182  West Bank and Gaza        10621        78         3752      6791
# 183      Western Sahara           10         1            8         1
# 184               Yemen         1691       483          833       375
# 185              Zambia         4552       140         2815      1597
# 186            Zimbabwe         2704        36          542      2126
#
#      NewCases_x  NewDeaths_x  NewRecovered_x  Deaths_per_100_cases  \
# ...

# %%
cleaned_merged_data=merged_data.copy()
cleaned_merged_data=merged_data.fillna(0)

# %%
cleaned_merged_data
# Out:
#                 Country  Confirmed_x  Deaths_x  Recovered_x  Active_x  \
# 0           Afghanistan        36263      1269        25198      9796
# 1               Albania         4880       144         2745      1991
# 2               Algeria        27973      1163        18837      7973
# 3               Andorra          907        52          803        52
# 4                Angola          950        41          242       667
# ..                  ...          ...       ...          ...       ...
# 182  West Bank and Gaza        10621        78         3752      6791
# 183      Western Sahara           10         1            8         1
# 184               Yemen         1691       483          833       375
# 185              Zambia         4552       140         2815      1597
# 186            Zimbabwe         2704        36          542      2126
#
#      NewCases_x  NewDeaths_x  NewRecovered_x  Deaths_per_100_cases  \
# ...

# %%
cleaned_merged_data.to_csv('mergeddata.csv',index=False)

# %%
cleaned_merged_data.dtypes
# Out:
# Country                      object
# Confirmed_x                   int64
# Deaths_x                      int64
# Recovered_x                   int64
# Active_x                      int64
# NewCases_x                    int64
# NewDeaths_x                   int64
# NewRecovered_x                int64
# Deaths_per_100_cases        float64
# Recovered_per_100_cases     float64
# Deaths_per_100_Recovered    float64
# Confirmed_last_week           int64
# 1_week_change                 int64
# 1_week_percent_increase     float64
# WHO_Region_x                 object
# Continent                    object
# Population                  float64
# Confirmed_y                 float64
# NewCases_y                  float64
# Deaths_y                    float64
# NewDeaths_y                 float64
# Recovered_y                 float64
# NewRecovered_y              float64
# Active_y                    float64
# Serious_or_Critical         float64
# Tot_Cases_per_1M_pop        float64
# ...

# %%
cleaned_merged_data.rename(columns={'Serious,Critical':'Serious_or_Critical' },inplace=True)
